# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.126)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
import os
import pandas as pd
import re
import numpy as np
from ultralytics import YOLO
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import joblib  # For saving and loading the model
import warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
warnings.filterwarnings("ignore")
plt.rcParams['font.sans-serif'] = ['SimHei']  # Set Chinese font

# Define parameters
dataset_dir = r'iss'  # Dataset directory, please modify according to the actual path
output_image_dir = 'output_images'  # Folder to save frame images
output_csv_path = 'output_keypoints_data.csv'  # CSV file to save joint data
os.makedirs(output_image_dir, exist_ok=True)

# %%
# Define names for the 17 keypoints
KEYPOINT_NAMES = [
    "Nose", "Right Eye", "Left Eye", "Right Ear", "Left Ear",
    "Right Shoulder", "Left Shoulder", "Right Elbow", "Left Elbow",
    "Right Wrist", "Left Wrist", "Right Hip", "Left Hip",
    "Right Knee", "Left Knee", "Right Ankle", "Left Ankle"
]

# define key points to keep
keypoints_to_keep = [
    'Right Shoulder', 'Left Shoulder', 'Right Elbow', 'Left Elbow',
    'Right Wrist', 'Left Wrist', 'Right Hip', 'Left Hip',
    'Right Knee', 'Left Knee', 'Right Ankle', 'Left Ankle'
]

# %%
# construct the column names to be processed
keypoint_columns = []
for kp in keypoints_to_keep:
    keypoint_columns.append(f'{kp}_x')
    keypoint_columns.append(f'{kp}_y')

# %%
# Define a function to calculate the new origin and coordinate normalization
def calculate_new_origin(keypoints_data):
    right_shoulder = keypoints_data[5][:2]
    left_shoulder = keypoints_data[6][:2]
    right_hip = keypoints_data[11][:2]
    left_hip = keypoints_data[12][:2]

    valid_points = [p for p in [right_shoulder, left_shoulder, right_hip, left_hip] if p[0] != 0 and p[1] != 0]
    if len(valid_points) == 0:
        raise ValueError("Missing keypoints for right shoulder, left shoulder, right hip, and left hip, cannot calculate new origin")

    x0 = sum([p[0] for p in valid_points]) / len(valid_points)
    y0 = sum([p[1] for p in valid_points]) / len(valid_points)
    return x0, y0

def get_min_max_of_new_coords(keypoints_data, x0, y0):#计算在新的坐标系下，所有有效关键点的 x 和 y 坐标的最小值和最大值。这是为了在新的坐标系中对关键点进行归一化。
    x_new_values = []
    y_new_values = []

    for keypoint in keypoints_data:
        x, y, conf = keypoint
        if conf > 0:  # Only compute valid keypoints
            x_new = x - x0
            y_new = -(y - y0)  # Y-axis grows from bottom to top
            x_new_values.append(x_new)
            y_new_values.append(y_new)

    x_min_new, x_max_new = min(x_new_values), max(x_new_values)
    y_min_new, y_max_new = min(y_new_values), max(y_new_values)

    return x_min_new, x_max_new, y_min_new, y_max_new

def parse_keypoints_with_custom_origin(results):
    parsed_keypoints_list = []
    for i in range(len(results)):
        keypoints_data = results[i].keypoints.data.cpu().numpy()[0]  # Retrieve keypoints (17, 3)

        # Calculate the new origin coordinates
        try:
            x0, y0 = calculate_new_origin(keypoints_data)
        except ValueError as e:
            print(f"Object {i} could not calculate a new origin: {e}")
            continue  # Skip this object

        # Calculate the min and max values of x_new and y_new in the new coordinate system
        x_min_new, x_max_new, y_min_new, y_max_new = get_min_max_of_new_coords(keypoints_data, x0, y0)

        object_keypoints = {"object_id": i}
        keypoint_dict = {}

        # Calculate each keypoint's coordinates relative to the new origin and normalize
        for j, keypoint in enumerate(keypoints_data):
            x, y, conf = keypoint
            if x == 0 and y == 0:
                keypoint_dict[KEYPOINT_NAMES[j]] = None
            else:
                # Coordinates in the new coordinate system, Y-axis grows from bottom to top
                x_new = x - x0
                y_new = -(y - y0)

                # Normalize the new coordinates
                if x_max_new != x_min_new:
                    x_normalized = (x_new - x_min_new) / (x_max_new - x_min_new)
                else:
                    x_normalized = 0  # Avoid division by zero if max equals min

                if y_max_new != y_min_new:
                    y_normalized = (y_new - y_min_new) / (y_max_new - y_min_new)
                else:
                    y_normalized = 0  # Avoid division by zero if max equals min

                keypoint_dict[KEYPOINT_NAMES[j]] = {
                    "name": KEYPOINT_NAMES[j],
                    "x": x_normalized,
                    "y": y_normalized,
                    "confidence": conf
                }

        object_keypoints["keypoints"] = keypoint_dict
        parsed_keypoints_list.append(object_keypoints)

    return parsed_keypoints_list

# %%
# Initialize a list to store data
all_data = []
all_data_new_video = []
# Load the YOLOv8 pose model
model = YOLO('yolov8n-pose.pt')

# %%
standard_dataset_dir = '/content/drive/MyDrive/iss/standard_video'
standard_output_image_dir = '/content/drive/MyDrive/iss/standard_output_images/'
# Traverse the entire dataset_fitness directory to find all video files
for root, dirs, files in os.walk(standard_dataset_dir):
    for file in files:
        if file.endswith('.mp4') or file.endswith('.MOV'):  # Process video files
            input_video_path = os.path.join(root, file)
            # Output the currently processing video file
            print(f"Processing video: {input_video_path}")
            # Extract action name and standard type
            video_info = input_video_path.split(os.sep)[-2:]  # Extract the last two parts as the action name and standard type
            action_name = re.sub(r'^\d+\s*', '', video_info[0])  # Remove leading numbers and spaces
            standard_type = video_info[1].split('.')[0]

            # Open the video file
            cap = cv2.VideoCapture(input_video_path)
            fps = cap.get(cv2.CAP_PROP_FPS)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            duration = frame_count / fps

            # Take 5 frames every 0.5 seconds
            frames_per_half_second = int(fps / 2)
            max_duration = 58.0  # Only process the first 60 seconds of the video
            max_frame_to_process = int(fps * max_duration)

            frame_indices = []
            for i in range(0, max_frame_to_process, frames_per_half_second):
                # Select 3 frames from the 5-frame interval
                for j in [0, 2, 4]:  # Select the 1st, 3rd, and 5th frames from the 5 frames
                    frame_index = i + j
                    if frame_index < max_frame_to_process:
                        frame_indices.append(frame_index)

            frame_indices = sorted(set(frame_indices))  # Ensure no duplicate frames, sort in order

            # Process the video frame by frame
            frame_number = 0
            sequence_number = 0

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                if frame_number in frame_indices:
                    # Use the model for detection
                    results = model(frame)
                    parsed_keypoints = parse_keypoints_with_custom_origin(results)

                    # Assign the same sequence number: frames within the same 0.5-second interval share the same sequence number
                    sequence_number = frame_number // frames_per_half_second

                    for obj in parsed_keypoints:
                        keypoints = obj['keypoints']
                        row_data = {
                            'action_name': action_name,
                            'standard_type': standard_type,
                            'frame_index': frame_number,
                            'sequence': sequence_number,
                        }
                        # Store the coordinates of each keypoint into row_data
                        for kp_name in KEYPOINT_NAMES:
                            kp_info = keypoints.get(kp_name, None)
                            if kp_info:
                                row_data[f'{kp_name}_x'] = kp_info['x']
                                row_data[f'{kp_name}_y'] = kp_info['y']
                            else:
                                row_data[f'{kp_name}_x'] = None
                                row_data[f'{kp_name}_y'] = None

                        all_data.append(row_data)

                    # Save the processed frame image
                    processed_frame = results[0].plot()

                    image_output_path = os.path.join(standard_output_image_dir,
                                                     f"{action_name}_{standard_type}_{frame_number}_{sequence_number}.jpg")
                    cv2.imwrite(image_output_path, processed_frame)  # Save the detection result image

                frame_number += 1

            # Release video resources
            cap.release()
# Out:
# Processing video: /content/drive/MyDrive/iss/standard_video/sample.mp4
#
# 0: 384x640 1 person, 102.7ms
# Speed: 4.3ms preprocess, 102.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.2ms
# Speed: 3.4ms preprocess, 101.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.3ms
# Speed: 2.3ms preprocess, 96.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Object 0 could not calculate a new origin: Missing keypoints for right shoulder, left shoulder, right hip, and left hip, cannot calculate new origin
#
# 0: 384x640 1 person, 98.7ms
# Speed: 2.9ms preprocess, 98.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Object 0 could not calculate a new origin: Missing keypoints for right shoulder, left shoulder, right hip, and left hip, cannot calculate new origin
#
# 0: 384x640 1 person, 96.2ms
# Speed: 2.5ms preprocess, 96.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Object 0 could not calculate a new origin: Missing keypoints for right shoulder, left shoulder, right hip, and left hip, cannot calculate new origin
#
# 0: 384x640 1 person, 97.8ms
# Speed: 1.8ms preprocess, 97.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.5ms
# Speed: 1.9ms preprocess, 97.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.8ms
# Speed: 1.6ms preprocess, 95.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 212.8ms
# Speed: 2.5ms preprocess, 212.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 152.8ms
# Speed: 3.1ms preprocess, 152.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 141.0ms
# Speed: 2.7ms preprocess, 141.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 194.6ms
# Speed: 4.5ms preprocess, 194.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 239.9ms
# Speed: 4.0ms preprocess, 239.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 138.3ms
# Speed: 4.5ms preprocess, 138.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.2ms
# Speed: 7.8ms preprocess, 151.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.4ms
# Speed: 1.6ms preprocess, 151.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 139.3ms
# Speed: 1.9ms preprocess, 139.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 224.5ms
# Speed: 2.8ms preprocess, 224.5ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.8ms
# Speed: 1.8ms preprocess, 151.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 219.6ms
# Speed: 2.2ms preprocess, 219.6ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.9ms
# Speed: 5.6ms preprocess, 177.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 120.2ms
# Speed: 2.2ms preprocess, 120.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.6ms
# Speed: 1.8ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.4ms
# Speed: 2.1ms preprocess, 94.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.0ms
# Speed: 1.7ms preprocess, 95.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.1ms
# Speed: 3.2ms preprocess, 96.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 2.3ms preprocess, 100.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.5ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 1.7ms preprocess, 99.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.3ms
# Speed: 2.4ms preprocess, 104.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.3ms
# Speed: 2.4ms preprocess, 97.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.0ms
# Speed: 2.8ms preprocess, 99.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.7ms preprocess, 102.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 2.1ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 2.0ms preprocess, 98.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.7ms
# Speed: 3.2ms preprocess, 104.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.8ms preprocess, 101.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.2ms
# Speed: 2.7ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.7ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 2.4ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.9ms
# Speed: 1.8ms preprocess, 94.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.0ms
# Speed: 1.7ms preprocess, 96.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 2.7ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 2.8ms preprocess, 99.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.5ms
# Speed: 2.9ms preprocess, 103.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.3ms
# Speed: 2.1ms preprocess, 94.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 1.7ms preprocess, 101.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 2.1ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.9ms
# Speed: 2.5ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.0ms
# Speed: 3.4ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.9ms
# Speed: 2.3ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 3.0ms preprocess, 102.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.6ms
# Speed: 1.6ms preprocess, 94.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.3ms
# Speed: 1.9ms preprocess, 94.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.6ms
# Speed: 1.6ms preprocess, 126.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 143.5ms
# Speed: 3.0ms preprocess, 143.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.5ms
# Speed: 2.5ms preprocess, 123.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.7ms
# Speed: 1.6ms preprocess, 123.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 133.5ms
# Speed: 1.8ms preprocess, 133.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.9ms
# Speed: 2.4ms preprocess, 137.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.7ms
# Speed: 2.3ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.6ms
# Speed: 2.3ms preprocess, 129.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.4ms
# Speed: 2.1ms preprocess, 134.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.3ms
# Speed: 1.7ms preprocess, 129.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.2ms
# Speed: 1.8ms preprocess, 134.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.2ms
# Speed: 2.8ms preprocess, 107.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.2ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.9ms
# Speed: 2.8ms preprocess, 97.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.9ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 2.8ms preprocess, 103.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.9ms
# Speed: 2.5ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.2ms
# Speed: 3.4ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.9ms
# Speed: 2.2ms preprocess, 108.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 2.8ms preprocess, 103.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.3ms preprocess, 101.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.9ms
# Speed: 2.9ms preprocess, 102.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.4ms
# Speed: 2.8ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.2ms preprocess, 100.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.2ms
# Speed: 2.0ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.2ms
# Speed: 3.1ms preprocess, 107.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 2.6ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.7ms preprocess, 100.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.0ms
# Speed: 2.7ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.5ms
# Speed: 2.0ms preprocess, 109.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 146.7ms
# Speed: 1.7ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.8ms
# Speed: 2.8ms preprocess, 155.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.3ms
# Speed: 2.9ms preprocess, 186.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 135.9ms
# Speed: 1.9ms preprocess, 135.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.5ms
# Speed: 1.7ms preprocess, 142.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.5ms
# Speed: 2.4ms preprocess, 108.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.4ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 3.9ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.0ms
# Speed: 1.8ms preprocess, 104.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 2.4ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.2ms
# Speed: 2.3ms preprocess, 96.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 2.5ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 3.1ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.1ms
# Speed: 2.7ms preprocess, 100.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.8ms
# Speed: 3.0ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.8ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.9ms
# Speed: 2.1ms preprocess, 108.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.5ms
# Speed: 3.3ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.7ms
# Speed: 1.9ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.8ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 3.2ms preprocess, 98.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 3.0ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.9ms
# Speed: 2.7ms preprocess, 104.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.9ms
# Speed: 2.8ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.8ms
# Speed: 2.9ms preprocess, 102.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.0ms
# Speed: 3.2ms preprocess, 107.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 2.8ms preprocess, 103.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.6ms
# Speed: 2.3ms preprocess, 103.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.7ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.9ms preprocess, 100.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.9ms
# Speed: 2.7ms preprocess, 106.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 2.6ms preprocess, 98.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.2ms
# Speed: 2.5ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.7ms
# Speed: 3.7ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.3ms
# Speed: 1.9ms preprocess, 97.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.1ms
# Speed: 3.4ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.6ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.9ms
# Speed: 2.8ms preprocess, 103.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.6ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 3.2ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 1.9ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.8ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 1.7ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.9ms
# Speed: 1.9ms preprocess, 97.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.3ms
# Speed: 1.9ms preprocess, 97.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.4ms
# Speed: 2.8ms preprocess, 111.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.3ms
# Speed: 2.1ms preprocess, 96.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.8ms preprocess, 102.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 3.3ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.9ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.6ms
# Speed: 2.6ms preprocess, 98.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.3ms
# Speed: 2.6ms preprocess, 112.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 144.7ms
# Speed: 2.6ms preprocess, 144.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.6ms
# Speed: 2.6ms preprocess, 134.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 121.8ms
# Speed: 1.7ms preprocess, 121.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.4ms
# Speed: 1.9ms preprocess, 127.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.8ms
# Speed: 3.0ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 131.9ms
# Speed: 2.4ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 124.1ms
# Speed: 1.7ms preprocess, 124.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.5ms
# Speed: 7.2ms preprocess, 126.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 139.0ms
# Speed: 1.8ms preprocess, 139.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.0ms
# Speed: 1.9ms preprocess, 126.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 130.3ms
# Speed: 3.2ms preprocess, 130.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.6ms
# Speed: 1.6ms preprocess, 98.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 2.3ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.8ms
# Speed: 2.7ms preprocess, 109.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 1.8ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 2.2ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.8ms
# Speed: 2.5ms preprocess, 106.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 2.1ms preprocess, 99.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.4ms preprocess, 101.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.7ms
# Speed: 3.1ms preprocess, 103.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.6ms
# Speed: 2.2ms preprocess, 104.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.4ms
# Speed: 2.5ms preprocess, 108.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.6ms
# Speed: 2.7ms preprocess, 98.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.6ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 140.8ms
# Speed: 2.7ms preprocess, 140.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.8ms
# Speed: 2.1ms preprocess, 95.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.7ms
# Speed: 2.1ms preprocess, 142.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 253.8ms
# Speed: 5.3ms preprocess, 253.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.7ms
# Speed: 1.9ms preprocess, 175.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 119.4ms
# Speed: 2.1ms preprocess, 119.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 3.1ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.7ms
# Speed: 2.3ms preprocess, 102.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 220.4ms
# Speed: 3.1ms preprocess, 220.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 372.6ms
# Speed: 2.9ms preprocess, 372.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.5ms
# Speed: 2.8ms preprocess, 110.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.0ms
# Speed: 2.0ms preprocess, 178.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 192.6ms
# Speed: 4.3ms preprocess, 192.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.7ms
# Speed: 6.6ms preprocess, 184.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.6ms
# Speed: 3.7ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.9ms
# Speed: 2.2ms preprocess, 159.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 198.1ms
# Speed: 5.5ms preprocess, 198.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 262.6ms
# Speed: 4.6ms preprocess, 262.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.9ms
# Speed: 1.9ms preprocess, 167.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 143.4ms
# Speed: 1.9ms preprocess, 143.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 152.0ms
# Speed: 2.2ms preprocess, 152.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 183.1ms
# Speed: 2.0ms preprocess, 183.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.7ms
# Speed: 6.1ms preprocess, 186.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.1ms
# Speed: 10.2ms preprocess, 186.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.4ms
# Speed: 4.2ms preprocess, 109.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.4ms
# Speed: 2.5ms preprocess, 104.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 137.1ms
# Speed: 6.4ms preprocess, 137.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.4ms
# Speed: 2.4ms preprocess, 116.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 4.3ms preprocess, 103.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.3ms
# Speed: 1.9ms preprocess, 106.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 1.9ms preprocess, 98.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.5ms
# Speed: 2.0ms preprocess, 106.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 3.0ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.9ms
# Speed: 1.9ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.2ms
# Speed: 2.0ms preprocess, 99.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 3.0ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.3ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 3.4ms preprocess, 98.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.3ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.6ms
# Speed: 3.2ms preprocess, 107.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 2.2ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.3ms
# Speed: 2.9ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 130.6ms
# Speed: 2.8ms preprocess, 130.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 134.3ms
# Speed: 1.7ms preprocess, 134.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.0ms
# Speed: 2.2ms preprocess, 129.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 132.8ms
# Speed: 2.9ms preprocess, 132.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 145.8ms
# Speed: 1.8ms preprocess, 145.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.9ms
# Speed: 2.9ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.7ms
# Speed: 1.9ms preprocess, 123.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 126.4ms
# Speed: 2.9ms preprocess, 126.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 136.3ms
# Speed: 1.6ms preprocess, 136.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 138.4ms
# Speed: 1.9ms preprocess, 138.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 139.6ms
# Speed: 2.6ms preprocess, 139.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.9ms
# Speed: 1.9ms preprocess, 97.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.3ms preprocess, 100.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 3.1ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.6ms
# Speed: 3.6ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.4ms
# Speed: 3.1ms preprocess, 100.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 106.0ms
# Speed: 2.8ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.4ms
# Speed: 1.6ms preprocess, 96.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.2ms
# Speed: 3.0ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.9ms preprocess, 100.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.8ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 3.0ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.9ms
# Speed: 2.2ms preprocess, 93.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.2ms
# Speed: 1.9ms preprocess, 103.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.1ms
# Speed: 3.1ms preprocess, 108.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.6ms
# Speed: 1.8ms preprocess, 98.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.0ms
# Speed: 2.5ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.8ms
# Speed: 2.8ms preprocess, 96.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 1.8ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.4ms
# Speed: 1.9ms preprocess, 96.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 96.4ms
# Speed: 2.9ms preprocess, 96.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.0ms
# Speed: 1.6ms preprocess, 98.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 3.0ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.3ms
# Speed: 1.4ms preprocess, 95.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 2.9ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.2ms
# Speed: 2.2ms preprocess, 99.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.8ms
# Speed: 2.5ms preprocess, 98.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 3.1ms preprocess, 100.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.8ms
# Speed: 2.8ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.7ms
# Speed: 1.9ms preprocess, 97.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.6ms
# Speed: 2.8ms preprocess, 110.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 1.8ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.3ms
# Speed: 2.9ms preprocess, 102.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 1.9ms preprocess, 98.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.9ms
# Speed: 1.8ms preprocess, 101.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.6ms
# Speed: 1.7ms preprocess, 97.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.9ms
# Speed: 2.4ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 1.8ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.5ms
# Speed: 2.7ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.0ms
# Speed: 1.5ms preprocess, 94.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.8ms
# Speed: 2.9ms preprocess, 105.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.7ms
# Speed: 3.4ms preprocess, 103.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.6ms
# Speed: 2.9ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.3ms
# Speed: 3.3ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 2.7ms preprocess, 99.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.8ms
# Speed: 2.8ms preprocess, 97.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.5ms
# Speed: 1.7ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 3.2ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.7ms
# Speed: 1.7ms preprocess, 94.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.1ms preprocess, 102.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.0ms
# Speed: 3.7ms preprocess, 96.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.9ms
# Speed: 2.3ms preprocess, 97.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.1ms
# Speed: 2.6ms preprocess, 98.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.9ms
# Speed: 3.4ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.6ms
# Speed: 2.4ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.2ms
# Speed: 2.6ms preprocess, 106.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.7ms
# Speed: 1.9ms preprocess, 96.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 2.8ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.7ms
# Speed: 3.1ms preprocess, 98.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 2.7ms preprocess, 98.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.4ms
# Speed: 2.7ms preprocess, 103.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.1ms
# Speed: 3.2ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.3ms
# Speed: 3.5ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.8ms
# Speed: 2.1ms preprocess, 95.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.6ms
# Speed: 2.1ms preprocess, 97.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 108.7ms
# Speed: 2.1ms preprocess, 108.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.1ms
# Speed: 3.2ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 2.1ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 107.6ms
# Speed: 3.0ms preprocess, 107.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 3.2ms preprocess, 97.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.9ms
# Speed: 3.1ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 3.1ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 3.2ms preprocess, 101.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.0ms
# Speed: 3.4ms preprocess, 104.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 2.7ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 123.9ms
# Speed: 1.8ms preprocess, 123.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.3ms
# Speed: 2.6ms preprocess, 164.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.7ms
# Speed: 2.2ms preprocess, 125.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 127.9ms
# Speed: 1.7ms preprocess, 127.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 131.8ms
# Speed: 3.6ms preprocess, 131.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 143.5ms
# Speed: 1.7ms preprocess, 143.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.9ms
# Speed: 2.5ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 147.3ms
# Speed: 1.8ms preprocess, 147.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 138.5ms
# Speed: 1.9ms preprocess, 138.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 148.8ms
# Speed: 2.6ms preprocess, 148.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 129.2ms
# Speed: 1.9ms preprocess, 129.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 1.8ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.1ms preprocess, 100.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 3.0ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.9ms
# Speed: 2.7ms preprocess, 96.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.9ms
# Speed: 3.0ms preprocess, 102.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 3.5ms preprocess, 97.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.6ms
# Speed: 2.2ms preprocess, 95.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.1ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.0ms
# Speed: 2.9ms preprocess, 98.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 3.0ms preprocess, 101.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.8ms
# Speed: 3.5ms preprocess, 99.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 2.3ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.4ms
# Speed: 3.0ms preprocess, 97.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 2.8ms preprocess, 100.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.8ms
# Speed: 2.0ms preprocess, 94.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.0ms
# Speed: 2.8ms preprocess, 98.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.1ms preprocess, 105.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 1.8ms preprocess, 97.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.3ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.5ms
# Speed: 3.0ms preprocess, 96.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 2.1ms preprocess, 97.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 3.5ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.6ms
# Speed: 2.6ms preprocess, 97.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.7ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.8ms
# Speed: 2.0ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.3ms
# Speed: 2.5ms preprocess, 98.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.7ms
# Speed: 2.3ms preprocess, 102.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.7ms
# Speed: 3.2ms preprocess, 103.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.2ms
# Speed: 1.8ms preprocess, 98.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 102.5ms
# Speed: 2.8ms preprocess, 102.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.5ms
# Speed: 3.1ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 3.1ms preprocess, 97.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 2.3ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.7ms
# Speed: 2.8ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.1ms
# Speed: 2.6ms preprocess, 97.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.3ms
# Speed: 3.0ms preprocess, 97.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 95.9ms
# Speed: 2.1ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 105.6ms
# Speed: 2.1ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.0ms
# Speed: 2.1ms preprocess, 100.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.3ms
# Speed: 2.7ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.4ms
# Speed: 3.1ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.3ms
# Speed: 1.9ms preprocess, 99.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 96.1ms
# Speed: 1.8ms preprocess, 96.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.7ms
# Speed: 3.1ms preprocess, 110.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.5ms
# Speed: 1.9ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 104.7ms
# Speed: 2.0ms preprocess, 104.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.0ms
# Speed: 2.7ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 2.1ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 98.8ms
# Speed: 1.7ms preprocess, 98.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.9ms
# Speed: 1.7ms preprocess, 98.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.6ms
# Speed: 3.6ms preprocess, 99.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 103.3ms
# Speed: 6.1ms preprocess, 103.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.6ms
# Speed: 2.1ms preprocess, 98.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 1.9ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.1ms
# Speed: 3.1ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Convert all data into a DataFrame
columns = ['action_name', 'standard_type', 'frame_index', 'sequence'] + [f'{k}_x' for k in KEYPOINT_NAMES] + [f'{k}_y' for k in KEYPOINT_NAMES]
data = pd.DataFrame(all_data, columns=columns)

# Save data to a CSV file
output_csv_path = '/content/drive/MyDrive/iss/standard_output_keypoints_data.csv'  # Path to save in Google Drive
data.to_csv(output_csv_path, index=False)
print("Data extraction completed and saved to CSV file.")
# Out:
# Data extraction completed and saved to CSV file.

# %%
# Input and output directory settings (second video)
new_dataset_dir = '/content/drive/MyDrive/iss/new_video'  # Standard video folder
new_output_image_dir = '/content/drive/MyDrive/iss/new_output_images/'  # Output image directory
output_csv_path = '/content/drive/MyDrive/iss/output_keypoints_data_second_video.csv'  # Output CSV file path

# Traverse the entire dataset_fitness directory to find all video files
for root, dirs, files in os.walk(new_dataset_dir):
    for file in files:
        if file.endswith('.mov') or file.endswith('.MOV'):  # Process video files
            input_video_path = os.path.join(root, file)
            # Output the currently processing video file
            print(f"Processing second video: {input_video_path}")
            # Extract action name and standard type
            video_info = input_video_path.split(os.sep)[-2:]  # Extract the last two parts as the action name and standard type
            action_name = re.sub(r'^\d+\s*', '', video_info[0])  # Remove leading numbers and spaces
            standard_type = video_info[1].split('.')[0]

            # Open the video file
            cap = cv2.VideoCapture(input_video_path)
            fps = cap.get(cv2.CAP_PROP_FPS)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            duration = frame_count / fps

            # Take 5 frames every 0.5 seconds
            frames_per_half_second = int(fps / 2)
            max_duration = 58.0  # Only process the first 60 seconds of the video
            max_frame_to_process = int(fps * max_duration)

            frame_indices = []
            for i in range(0, max_frame_to_process, frames_per_half_second):
                # Select 3 frames from the 5-frame interval
                for j in [0, 2, 4]:  # Select the 1st, 3rd, and 5th frames from the 5 frames
                    frame_index = i + j
                    if frame_index < max_frame_to_process:
                        frame_indices.append(frame_index)

            frame_indices = sorted(set(frame_indices))  # Ensure no duplicate frames, sort in order

            # Process the video frame by frame
            frame_number = 0
            sequence_number = 0

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                if frame_number in frame_indices:
                    # Use the model for detection
                    results = model(frame)
                    parsed_keypoints = parse_keypoints_with_custom_origin(results)

                    # Assign the same sequence number: frames within the same 0.5-second interval share the same sequence number
                    sequence_number = frame_number // frames_per_half_second

                    for obj in parsed_keypoints:
                        keypoints = obj['keypoints']
                        row_data = {
                            'action_name': action_name,
                            'standard_type': standard_type,
                            'frame_index': frame_number,
                            'sequence': sequence_number,
                        }
                        # Store the coordinates of each keypoint into row_data
                        for kp_name in KEYPOINT_NAMES:
                            kp_info = keypoints.get(kp_name, None)
                            if kp_info:
                                row_data[f'{kp_name}_x'] = kp_info['x']
                                row_data[f'{kp_name}_y'] = kp_info['y']
                            else:
                                row_data[f'{kp_name}_x'] = None
                                row_data[f'{kp_name}_y'] = None

                        all_data_new_video.append(row_data)

                    # Save the processed frame image
                    processed_frame = results[0].plot()

                    image_output_path = os.path.join(new_output_image_dir,
                                                     f"{action_name}_{standard_type}_{frame_number}_{sequence_number}.jpg")
                    cv2.imwrite(image_output_path, processed_frame)  # Save the detection result image

                frame_number += 1

            # Release video resources
            cap.release()
# Out:
# Processing second video: /content/drive/MyDrive/iss/new_video/IMG_3945 2.mov
#
# 0: 640x416 1 person, 123.7ms
# Speed: 4.0ms preprocess, 123.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 121.0ms
# Speed: 3.0ms preprocess, 121.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 107.8ms
# Speed: 2.6ms preprocess, 107.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 103.3ms
# Speed: 1.7ms preprocess, 103.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 101.5ms
# Speed: 2.5ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.5ms
# Speed: 2.1ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 101.9ms
# Speed: 2.9ms preprocess, 101.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.8ms
# Speed: 3.2ms preprocess, 102.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.0ms
# Speed: 2.7ms preprocess, 104.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 105.1ms
# Speed: 2.2ms preprocess, 105.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 105.0ms
# Speed: 2.4ms preprocess, 105.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.5ms
# Speed: 2.2ms preprocess, 104.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 107.4ms
# Speed: 2.8ms preprocess, 107.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.2ms
# Speed: 2.5ms preprocess, 104.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.1ms
# Speed: 2.6ms preprocess, 104.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 103.3ms
# Speed: 2.4ms preprocess, 103.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.3ms
# Speed: 2.2ms preprocess, 104.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.6ms
# Speed: 2.2ms preprocess, 102.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 103.6ms
# Speed: 1.9ms preprocess, 103.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 106.9ms
# Speed: 2.5ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 103.6ms
# Speed: 1.9ms preprocess, 103.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 102.1ms
# Speed: 2.1ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 102.5ms
# Speed: 2.3ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 106.2ms
# Speed: 2.5ms preprocess, 106.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 104.7ms
# Speed: 2.1ms preprocess, 104.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 102.5ms
# Speed: 2.4ms preprocess, 102.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 102.1ms
# Speed: 1.8ms preprocess, 102.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 103.2ms
# Speed: 2.2ms preprocess, 103.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 3 persons, 103.5ms
# Speed: 2.5ms preprocess, 103.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.9ms
# Speed: 2.2ms preprocess, 100.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 101.1ms
# Speed: 2.4ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.2ms
# Speed: 2.1ms preprocess, 100.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 104.0ms
# Speed: 2.6ms preprocess, 104.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 103.1ms
# Speed: 2.3ms preprocess, 103.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 101.9ms
# Speed: 2.7ms preprocess, 101.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.2ms
# Speed: 2.3ms preprocess, 100.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 101.0ms
# Speed: 2.2ms preprocess, 101.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.9ms
# Speed: 2.2ms preprocess, 100.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.5ms
# Speed: 1.8ms preprocess, 100.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 101.2ms
# Speed: 2.2ms preprocess, 101.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 100.9ms
# Speed: 1.7ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 109.4ms
# Speed: 2.8ms preprocess, 109.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.2ms
# Speed: 1.6ms preprocess, 102.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 100.1ms
# Speed: 1.5ms preprocess, 100.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 105.4ms
# Speed: 2.7ms preprocess, 105.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 99.7ms
# Speed: 2.2ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 99.6ms
# Speed: 2.2ms preprocess, 99.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 99.7ms
# Speed: 2.1ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 2 persons, 105.9ms
# Speed: 2.1ms preprocess, 105.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.9ms
# Speed: 1.4ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 104.5ms
# Speed: 2.1ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 99.9ms
# Speed: 1.7ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.1ms
# Speed: 2.7ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 person, 102.7ms
# Speed: 2.2ms preprocess, 102.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)

# %%
# Convert all data into a DataFrame
columns = ['action_name', 'standard_type', 'frame_index', 'sequence'] + [f'{k}_x' for k in KEYPOINT_NAMES] + [f'{k}_y' for k in KEYPOINT_NAMES]
data = pd.DataFrame(all_data_new_video, columns=columns)

# Save data to a CSV file
new_output_csv_path = '/content/drive/MyDrive/iss/new_output_keypoints_data.csv'  # Path to save in Google Drive
data.to_csv(output_csv_path, index=False)
print("Data extraction completed and saved to CSV file.")
# Out:
# Data extraction completed and saved to CSV file.

# %%
import pandas as pd
import numpy as np

# Read the CSV files of the standard video and the new video
standard_data = pd.read_csv('/content/drive/MyDrive/iss/standard_output_keypoints_data.csv')  # Path to the CSV of the standard video
new_data = pd.read_csv('/content/drive/MyDrive/iss/output_keypoints_data_second_video.csv')  # Path to the CSV of the new video

# Select the keypoints to compare
important_keypoints = [
    "Right Shoulder", "Left Shoulder", "Right Elbow", "Left Elbow",
    "Right Knee", "Left Knee", "Right Ankle", "Left Ankle"
]

# Set threshold T, assuming the threshold is 0.1, meaning the maximum allowed deviation is 0.1
T = 0.1  # You can adjust this value based on actual requirements

# Calculate total number of frames
total_frames = len(standard_data)

# Deduction standard when each keypoint exceeds the threshold
penalty_per_keypoint = 100 / total_frames

# Initialize the total score
total_score = 100  # Initial score is 100

# Get the minimum number of frames from both datasets
total_frames = min(len(standard_data), len(new_data))

# Iterate through each frame to calculate the score
for i in range(total_frames):
    standard_row = standard_data.iloc[i]
    new_row = new_data.iloc[i]

    # Initial score for each frame (100 points)
    frame_score = 100

    for kp_name in important_keypoints:
        standard_x = standard_row[f'{kp_name}_x']
        standard_y = standard_row[f'{kp_name}_y']
        new_x = new_row[f'{kp_name}_x']
        new_y = new_row[f'{kp_name}_y']

        # Check if the keypoint is valid
        if standard_x is not None and new_x is not None and standard_y is not None and new_y is not None:
            # Calculate the Euclidean distance
            diff = np.sqrt((standard_x - new_x)**2 + (standard_y - new_y)**2)

            # If the deviation exceeds the threshold, deduct points proportionally, the greater the deviation, the more points are deducted
            if diff > T:
                # Increase the penalty based on the deviation and threshold, increasing the deduction
                penalty = (diff - T) * 100 / (1 - T)  # Calculate the deduction ratio based on deviation, increasing the penalty intensity
                frame_score -= penalty

    # Ensure that the score for each frame is not lower than 0
    frame_score = max(frame_score, 0)

    # Update the total score
    total_score = (total_score + frame_score) / 2  # Add each frame's score to the total score (average)

# Output the final total score
print(f"Total Score: {total_score}")
# Out:
# Total Score: 41.91355701196365
